# %% [markdown]
# <a href="https://colab.research.google.com/github/kashisabari2008-cpu/ict_assignments/blob/main/assignment03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# question 1

# %%
# Write a Python function to find the Max of three numbers

# %%
max(12,33,45)
# Out:
# 45

# %% [markdown]
# question 2

# %%
list=[18, 12, 30,10, 7]
s=0
for i in list:
    s=s+i
print(s)
# Out:
# 77

# %% [markdown]
# question 3

# %%
number=[23,44,55,77,99]

# %%
number.insert(2,88)

# %%
number
# Out:
# [23, 44, 88, 55, 77, 99]

# %% [markdown]
# question 4

# %%
sample_dict = { "name": "Kelly", "age":25, "salary": 8000, "city": "New york"}
sample_dict.pop("city")
sample_dict.update({"location":"New york"})

# %%
sample_dict
# Out:
# {'name': 'Kelly', 'age': 25, 'salary': 8000, 'location': 'New york'}

# %% [markdown]
# question 5

# %%
sample_dict = {
 'emp1': {'name': 'Jhon', 'salary': 7500},
 'emp2': {'name': 'Emma', 'salary': 8000},
 'emp3': {'name': 'Brad', 'salary': 500}
}
sample_dict['emp3']['salary'] = 8500
print(sample_dict)
# Out:
# {'emp1': {'name': 'Jhon', 'salary': 7500}, 'emp2': {'name': 'Emma', 'salary': 8000}, 'emp3': {'name': 'Brad', 'salary': 8500}}

# %% [markdown]
# question 6

# %%
tuple1 = (11, 22, 33, 44, 55, 66)

new_tuple =(tuple1[3],tuple1[4])

print(new_tuple)
# Out:
# (44, 55)

# %% [markdown]
# question 7

# %%
tuple1 = (50, 10, 60, 70, 50,83,567,50,81)
count_50 = tuple1.count(50)
print(f"The number of occuirence of 50 is: {count_50}")
# Out:
# The number of occuirence of 50 is: 3
