# %% [markdown]
# <a href="https://colab.research.google.com/github/kashisabari2008-cpu/ict_assignments/blob/main/Assignment02_Sabari.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.

# %%
n = int(input("Enter a number: "))
if n%3 == 0 and n%5 == 0:
 print ("FizzBuzz")
elif n%3 == 0:
 print("Fizz")
elif n%5 == 0:
 print("Buzz")
else:
  print(n)
# Out:
# Enetr a number: 5
# Buzz

# %% [markdown]
# # 2.

# %%
n = int(input("Enter the amount of unit consumed: "))
amount = 0
if n<=100:
 amount = n*5
elif n<=200:
 amount = (100*5) + (n-100) * 7
else:
 amount = (100*5) + (100*7) + ((n-200)*10)
print("Total amount:", amount)
# Out:
# Enter the amount of unit consumed: 245
# Total amount: 1650

# %% [markdown]
# # 3.

# %%
for i in range(1,6):
 print(i*"*")
# Out:
# *
# **
# ***
# ****
# *****

# %% [markdown]
# # 4.

# %%
al = str(input("Enter a number or string:"))
rev_pal = pal[::-1]

if rev_pal == pal:
print(pal,"is a palindrome")
else:
print(pal,"is not a palindrome")
